# lr_0055_grok = {61: 1739.0, 89: 1266.111111111111, 97: 1226.6666666666667, 113: 1095.6666666666667, 131: 961.0, 157: 872.1111111111111, 193: 831.4444444444445, 239: 789.5555555555555, 269: 783.8888888888889, 277: 761.2222222222222, 307: 770.2222222222222, 331: 782.7777777777778}

# Define x and y data for curve fitting
x_data = np.array(list(lr_022_train.keys()))
y_data_lr_022_train = np.array(list(lr_022_train.values()))
y_data_lr_022_grok = np.array(list(lr_022_grok.values()))
y_data_lr_011_train = np.array(list(lr_011_train.values()))
y_data_lr_011_grok = np.array(list(lr_011_grok.values()))
y_data_lr_0055_train = np.array(list(lr_0055_train.values()))
y_data_lr_0055_grok = np.array(list(lr_0055_grok.values()))

# Perform curve fitting
params_lr_022_train, _ = curve_fit(power_law, x_data, y_data_lr_022_train)
params_lr_022_grok, _ = curve_fit(power_law, x_data, y_data_lr_022_grok)
params_lr_011_train, _ = curve_fit(power_law, x_data, y_data_lr_011_train)
params_lr_011_grok, _ = curve_fit(power_law, x_data, y_data_lr_011_grok)
params_lr_0055_train, _ = curve_fit(power_law, x_data, y_data_lr_0055_train)
params_lr_0055_grok, _ = curve_fit(power_law, x_data, y_data_lr_0055_grok)

# Generate fitted data
y_fit_lr_022_train = power_law(x_data, *params_lr_022_train)
y_fit_lr_022_grok = power_law(x_data, *params_lr_022_grok)
y_fit_lr_011_train = power_law(x_data, *params_lr_011_train)
y_fit_lr_011_grok = power_law(x_data, *params_lr_011_grok)
y_fit_lr_0055_train = power_law(x_data, *params_lr_0055_train)
y_fit_lr_0055_grok = power_law(x_data, *params_lr_0055_grok)

# Create a figure and a set of subplots
fig, axs = plt.subplots(2, figsize=(10, 10))

# Plotting the training times
axs[0].plot(x_data, y_data_lr_022_train, marker='o', linestyle='', label='Train LR=0.022')
axs[0].plot(x_data, y_data_lr_011_train, marker='o', linestyle='', label='Train LR=0.011')
axs[0].plot(x_data, y_data_lr_0055_train, marker='o', linestyle='', label='Train LR=0.0055')
axs[0].plot(x_data, y_fit_lr_022_train, linestyle='--', label=f'Train Fit LR=0.022: {params_lr_022_train[0]:.2f}x^{params_lr_022_train[1]:.2f}')
axs[0].plot(x_data, y_fit_lr_011_train, linestyle='--', label=f'Train Fit LR=0.011: {params_lr_011_train[0]:.2f}x^{params_lr_011_train[1]:.2f}')
axs[0].plot(x_data, y_fit_lr_0055_train, linestyle='--', label=f'Train Fit LR=0.0055: {params_lr_0055_train[0]:.2f}x^{params_lr_0055_train[1]:.2f}')
axs[0].set_title('Training Times')
axs[0].set_xlabel('Prime Numbers')
axs[0].set_ylabel('Time')
axs[0].legend()

# Plotting the Grok (Test) times
axs[1].plot(x_data, y_data_lr_022_grok, marker='o', linestyle='', label='Grok LR=0.022')
axs[1].plot(x_data, y_data_lr_011_grok, marker='o', linestyle='', label='Grok LR=0.011')
axs[1].plot(x_data, y_data_lr_0055_grok, marker='o', linestyle='', label='Grok LR=0.0055')
axs[1].plot(x_data, y_fit_lr_022_grok, linestyle='--', label=f'Grok Fit LR=0.022: {params_lr_022_grok[0]:.2f}x^{params_lr_022_grok[1]:.2f}')
axs[1].plot(x_data, y_fit_lr_011_grok, linestyle='--', label=f'Grok Fit LR=0.011: {params_lr_011_grok[0]:.2f}x^{params_lr_011_grok[1]:.2f}')
axs[1].plot(x_data, y_fit_lr_0055_grok, linestyle='--', label=f'Grok Fit LR=0.0055: {params_lr_0055_grok[0]:.2f}x^{params_lr_0055_grok[1]:.2f}')
axs[1].set_title('Grok (Test) Times')
axs[1].set_xlabel('Prime Numbers')
axs[1].set_ylabel('Time')
axs[1].legend()

# Display the figure
plt.tight_layout()
plt.show()

# %%
# Data initialization for all three learning rates
lr_022_grok= {61: 788.8888888888889, 89: 591.5555555555555, 97: 590.6666666666666, 113: 526.1111111111111,
                  131: 485.1111111111111, 157: 424.1111111111111, 193: 405.3333333333333, 239: 388.44444444444446,
                  269: 375.77777777777777, 277: 373.8888888888889, 307: 381.1111111111111, 331: 368.77777777777777,
                  347: 367.44444444444446, 367: 372.22222222222223, 389: 369.6666666666667, 419: 371.3333333333333,
                  967: 386.1666666666667}
lr_022_train = {61: 234.88888888888889, 89: 253.11111111111111, 97: 256.77777777777777, 113: 266.77777777777777,
                   131: 278.1111111111111, 157: 277.8888888888889, 193: 287.0, 239: 296.6666666666667,
                   269: 297.55555555555554, 277: 296.77777777777777, 307: 303.44444444444446, 331: 305.55555555555554,
                   347: 308.1111111111111, 367: 308.6666666666667, 389: 313.8888888888889, 419: 316.44444444444446,
                   967: 355.8333333333333}
x_data = np.array(list(lr_022_train.keys()))

difference_times_022 = [train - grok for train, grok in zip(lr_022_train, lr_022_grok)]

y_data_lr_022_train = np.array(list(lr_022_train.values()))
y_data_lr_022_grok = np.array(list(lr_022_grok.values()))
fig, axs = plt.subplots(2, figsize=(10, 10))

axs[0].plot(x_data, y_data_lr_022_train, marker='o', linestyle='', label='Train LR=0.022')
axs[0].plot(x_data, y_data_lr_022_grok, marker='o', linestyle='', label='Grok LR=0.022')
# axs[0].plot(x_data, y_data_difference_times_022, marker='o', linestyle='', label='Train LR=0.0055')

axs[0].set_title('Training Times')
axs[0].set_xlabel('Prime Numbers')
axs[0].set_ylabel('Time')
axs[0].legend()
plt.tight_layout()
plt.show()
